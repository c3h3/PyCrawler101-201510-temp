# %%
url = "http://ecshweb.pchome.com.tw/search/v3.3/all/results?q=sony&page=2"

# %%
import requests

# %%
import urllib, urllib2

# %%
res = requests.get(url)

# %%
import pandas as pd

# %%
df2 = pd.DataFrame(res.json()["prods"])

# %%
pd.concat([df,df2])
# Out:
#                   Id author brand  cateId  \
# 0   DYAF3V-A9006DHKD               DYAQA6
# 1   DYAQ6F-A9006GA7Y               DYAQAR
# 2   DYAD2L-A9006GB4Q               DYAD2L
# 3   DYAD27-A90066O9Y               DYAD27
# 4   DYAD2J-A9006FRQ9               DYAD2J
# 5   DYAD27-A9006G8CA               DYAD27
# 6   DGALTU-A9005H1X3               DYAD00
# 7   DGBJA7-190066MAA               DGBJA7
# 8   DGAD01-A64596174               DGAD01
# 9   DYAD26-A90066KI0               DYAD26
# 10  DGALTH-A9005E9LH               DYAD08
# 11  DYAD2L-A9006GNMZ               DYAD2L
# 12  DGAD01-A90054RYV               DGAD01
# 13  DGBT30-A900649ND               DYAQA6
# 14  DGALS8-A9005ETN5               DYAD0B
# 15  DYAI49-A9006GL79               DYAI49
# 16  DGALTV-A9005G0C1               DYAD01
# 17  DGBT30-A9005D6OV               DYAQA6
# 18  DCAQ21-A900670VY               DCAQ21
# 19  DGAD01-A90067X1Y               DGAD01
# 0   DGBT1I-A90064873               DYAQA6
# ...

# %%
url = "http://mops.twse.com.tw/mops/web/t51sb01"

# %%
res = requests.get(url)

# %%
res.encoding
# Out:
# 'ISO-8859-1'

# %%
res.encoding = "utf8"

# %%
from pyquery import PyQuery

# %%
S= PyQuery(res.text)

# %%
S("form").map(lambda i,e: PyQuery(e)("select").attr("name"))
# Out:
# ['select', 'TYPEK']

# %%
postData = {"encodeURIComponent":1,
            "step":1,
            "firstin":1,
            "TYPEK":"sii",
            "code":""}

# %%
postUrl = "http://mops.twse.com.tw/mops/web/ajax_t51sb01"

# %%
res = requests.post(postUrl,data=postData)

# %%
res.encoding = "utf8"

# %%
df = pd.read_html(res.text)[0]

# %%
df
# Out:
#        0                 1                       2         3     4      5   \
# 0    公司代號              公司名稱                      住址  營利事業統一編號   董事長    總經理
# 1    1101        台灣水泥股份有限公司           台北市中山北路2段113號  11913502   辜成允    辜成允
# 2    1102        亞洲水泥股份有限公司  台北市大安區敦化南路2段207號30、31樓  03244509   徐旭東    李坤炎
# 3    1103        嘉新水泥股份有限公司            台北市中山北路2段96號  11892801   張剛綸    祁士鉅
# 4    1104        環球水泥股份有限公司        台北市南京東路二段125號10樓  07568009   侯博義    侯博義
# 5    1108        幸福水泥股份有限公司           台北市松江路237號15樓  40601248   陳兩傳    陳兩傳
# 6    1109        信大水泥股份有限公司             台北市寶慶路37號7樓  03279507   楊德雄    楊德雄
# 7    1110        東南水泥股份有限公司       高雄市前金區五福三路21號4樓之1  83078600   陳敏斷    吳長直
# 8    1201      味全食品工業股份有限公司              台北市松江路125號  11347802   李鳳翱    蘇守斌
# 9    1203          味王股份有限公司          台北市中山北路二段79號5樓  07067309  穎川建忠    陳恭平
# 10   1210      大成長城企業股份有限公司            台南市永康區蔦松二街三號  73008303   韓家宇    莊坤炎
# ...
